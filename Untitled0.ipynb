# %% [markdown]
# <a href="https://colab.research.google.com/github/lnbhy/AlgorithmLearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print("--- GPU and CUDA Information (from nvidia-smi) ---")
# !nvidia-smi

print("\n--- PyTorch and CUDA Status ---")
if torch.cuda.is_available():
    print(f"CUDA is available: Yes")
    print(f"Current CUDA device: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is available: No")
print(f"PyTorch version: {torch.__version__}")
# Out:
# --- GPU and CUDA Information (from nvidia-smi) ---
# Thu Jan  8 04:21:49 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# ...

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available!")
    print("Current CUDA device:", torch.cuda.get_device_name(0))
else:
    print("CUDA is not available.")
# Out:
# CUDA is available!
# Current CUDA device: Tesla T4
